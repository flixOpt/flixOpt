# %%
# %matplotlib inline

# %% [markdown]
# Created on Thu Jun 16 11:19:17 2022
# developed by Felix Panitz* and Peter Stange*
# * at Chair of Building Energy Systems and Heat Supply, Technische Universität Dresden

# %%
import numpy as np
import datetime
from flixOpt.flixStructure import *
from flixOpt.flixComps import *
from flixOpt.flixBasicsPublic import *

# ## Solver-Inputs:##
displaySolverOutput = False # ausführlicher Solver-Output.
displaySolverOutput = True  # ausführlicher Solver-Output.
gapFrac = 0.0001
timelimit = 3600

# solver_name = 'glpk' # warning, glpk quickly has numerical problems with big and epsilon
# solver_name = 'gurobi'
solver_name    = 'cbc'
nrOfThreads    = 1

# ## calculation-options - you can vary! ###
useCHPwithLinearSegments = False
# useCHPwithLinearSegments = True
checkPenalty    = False  
excessCosts = None
excessCosts = 1e5 # default value
################


# ## timeseries ##
P_el_Last = [70., 80., 90., 90 , 90 , 90, 90, 90, 90]
if checkPenalty :
    Q_th_Last = [30., 0., 90., 110, 2000 , 20, 20, 20, 20]
else :
    Q_th_Last = [30., 0., 90., 110, 110 , 20, 20, 20, 20]

p_el      = [40., 40., 40., 40 , 40, 40, 40, 40, 40]
   
aTimeSeries = datetime.datetime(2020, 1,1) +  np.arange(len(Q_th_Last)) * datetime.timedelta(hours=1)
aTimeSeries = aTimeSeries.astype('datetime64')

# %%
print('#######################################################################')
print('################### start of modeling #################################')


# ## Bus-Definition: ##
# Out:
# #######################################################################
# ################### start of modeling #################################

# %% [markdown]
#                 Typ         Name

# %%
Strom = cBus('el', 'Strom', excessCostsPerFlowHour=excessCosts)
Fernwaerme = cBus('heat', 'Fernwärme', excessCostsPerFlowHour=excessCosts)
Gas = cBus('fuel', 'Gas', excessCostsPerFlowHour=excessCosts)


# Effect-Definition:
costs = cEffectType('costs','€'      , 'Kosten', isStandard = True, isObjective = True)
CO2   = cEffectType('CO2'  ,'kg'     , 'CO2_e-Emissionen', 
                    specificShareToOtherEffects_operation = {costs: 0.2}, 
                    )
PE    = cEffectType('PE'   ,'kWh_PE' , 'Primärenergie', max_Sum = 3.5e3  )
# Out:
# Name 'Fernwärme' ist nicht Attributnamen-konform und wird zu 'Fernwaerme' geändert

# %% [markdown]
# ## definition of components ##
# ###############################

# %%
# 1. definition of boiler #
# 1. a) investment-options:
invest_Gaskessel = cInvestArgs(fixCosts = 1000, # 1000 € investment costs
                               investmentSize_is_fixed = True, # fix nominal size
                               investment_is_optional=False,# forced investment
                               specificCosts= {costs:10, PE:2}, # specific costs: 10 €/kW; 2 kWh_PE/kW
                               )
# invest_Gaskessel = None #
# 1. b) boiler itself:
aGaskessel = cKessel('Kessel', 
                     eta = 0.5, # efficiency ratio
                     costsPerRunningHour = {costs:0, CO2:1000}, # 1000 kg_CO2/h (just for testing)
                     # defining flows:
                     Q_th = cFlow(label   = 'Q_th', # name
                                  bus = Fernwaerme, # linked bus
                                  nominal_val = 50, # 50 kW_th nominal size
                                  loadFactor_max = 1.0, # maximal mean power 50 kW
                                  loadFactor_min = 0.1, # minimal mean power 5 kW
                                  min_rel = 5/50, # 10 % part load
                                  max_rel = 1, # 50 kW
                                  onHoursSum_min = 0, # minimum of working hours
                                  onHoursSum_max = 1000, # maximum of working hours
                                  onHours_max = 10, # maximum of working hours in one step
                                  offHours_max = 10, # maximum of off hours in one step
                                  # onHours_min = 2, # minimum on hours in one step
                                  # offHours_min = 4, # minimum off hours in one step
                                  switchOnCosts = 0.01, # € per start
                                  switchOn_maxNr = 1000, # max nr of starts
                                  valuesBeforeBegin=[50], # 50 kW is value before start
                                  investArgs = invest_Gaskessel, # see above
                                  sumFlowHours_max = 1e6, # kWh, overall maximum "flow-work"
                                  ),
                     Q_fu = cFlow(label = 'Q_fu', # name
                                  bus = Gas, # linked bus
                                  nominal_val = 200, # kW
                                  min_rel = 0, 
                                  max_rel = 1)) 

# 2. defining of CHP-unit:
aKWK  = cKWK('BHKW2', eta_th = 0.5, eta_el = 0.4, switchOnCosts =  0.01,
            P_el = cFlow('P_el',bus = Strom     , nominal_val = 60, min_rel = 5/60, ),
            Q_th = cFlow('Q_th',bus = Fernwaerme, nominal_val = 1e3),
            Q_fu = cFlow('Q_fu',bus = Gas, nominal_val = 1e3),on_valuesBeforeBegin = [1])


# 3. defining a alternative CHP-unit with linear segments :
# defining flows:
#   (explicitly outside, because variables 'P_el', 'Q_th', 'Q_fu' must be picked 
#    in segment definition)
P_el = cFlow('P_el', bus=Strom, nominal_val=60, max_rel=55)
Q_th = cFlow('Q_th', bus=Fernwaerme)
Q_fu = cFlow('Q_fu', bus=Gas)
# linear segments (eta-definitions than become useless!):
segmentsOfFlows = ({P_el: [5  ,30, 40,60 ], # elements an be list (timeseries)
                   Q_th: [6  ,35, 45,100], 
                   Q_fu: [12 ,70, 90,200]})

aKWK2 = cBaseLinearTransformer('BHKW2', inputs = [Q_fu], outputs = [P_el, Q_th], segmentsOfFlows = segmentsOfFlows, switchOnCosts = 0.01, on_valuesBeforeBegin = [1])



# 4. definition of storage:
# 4.a) investment options:
    

# linear segments of costs: [start1, end1, start2, end2, ...]
costsInvestsizeSegments = [[5,25,25,100], #kW
                           {costs:[50,250,250,800],#€
                            PE:[5,25,25,100] #kWh_PE
                            }
                           ]
# Anmerkung: points also realizable, through same start- end endpoint, i.g. [4,4]


# # alternative input only for standard-effect:
# costsInvestsizeSegments = [[5,25,25,100], #kW
#                             [50,250,250,800],#€ (standard-effect)
#                           ]

invest_Speicher = cInvestArgs(fixCosts = 0, # no fix costs
                              investmentSize_is_fixed = False, # variable size
                              costsInInvestsizeSegments = costsInvestsizeSegments, # see above
                              investment_is_optional=False, # forced invest
                              specificCosts= {costs: 0.01, CO2: 0.01}, # €/kWh; kg_CO2/kWh
                              min_investmentSize=0, max_investmentSize=1000) # optimizing between 0...1000 kWh

# 4.b) storage itself:
aSpeicher = cStorage('Speicher',
                     # defining flows:
                     inFlow  = cFlow('Q_th_load', bus = Fernwaerme, nominal_val = 1e4),
                     outFlow = cFlow('Q_th_unload',bus = Fernwaerme, nominal_val = 1e4),
                     capacity_inFlowHours=None, # None, because invest-size is variable
                     chargeState0_inFlowHours=0, # empty storage at beginning
                     # charge_state_end_min = 3, # min charge state and end
                     charge_state_end_max=10, # max charge state and end
                     eta_load=0.9, eta_unload=1, # efficiency of (un)-loading
                     fracLossPerHour=0.08, # loss of storage per time
                     avoidInAndOutAtOnce=True, # no parallel loading and unloading
                     investArgs=invest_Speicher) # see above
 

# 5. definition of sinks and sources:
# 5.a) heat load profile:    
aWaermeLast = cSink('Wärmelast',
                    sink = cFlow('Q_th_Last', # name
                                 bus = Fernwaerme, # linked bus
                                 nominal_val = 1, 
                                 min_rel = 0,
                                 val_rel = Q_th_Last)) # fixed values val_rel * nominal_val
# 5.b) gas tarif:
aGasTarif = cSource('Gastarif',
                    source = cFlow('Q_Gas',
                                   bus = Gas, # linked bus
                                   nominal_val = 1000, # defining nominal size
                                   costsPerFlowHour= {costs: 0.04, CO2: 0.3})) 
# 5.c) feed-in of electricity:
aStromEinspeisung = cSink('Einspeisung',
                          sink = cFlow('P_el',
                                       bus = Strom, # linked bus
                                       costsPerFlowHour = -1*np.array(p_el)))# feed-in tariff
# Out:
# Name 'Wärmelast' ist nicht Attributnamen-konform und wird zu 'Waermelast' geändert

# %% [markdown]
# ## Build energysystem ##
# #########################

# %%
es = cEnergySystem(aTimeSeries, dt_last=None) # creating System

es.addEffects(costs, CO2, PE) # adding effects
es.addComponents(aGaskessel, aWaermeLast, aGasTarif) # adding components
es.addComponents(aStromEinspeisung) # adding components

if useCHPwithLinearSegments:
    es.addComponents(aKWK2) # adding components
else:
    es.addComponents(aKWK) # adding components
    
es.addComponents(aSpeicher) # adding components
# Out:
# Register new effect costs
# Register new effect CO2
# Register new effect PE
# Register new Component Kessel
# Register new Component Waermelast
# Register new Component Gastarif
# Register new Component Einspeisung
# Register new Component BHKW2
# Register new Component Speicher

# %% [markdown]
# ## modeling and calculation ##
# ###############################

# %%
chosenEsTimeIndexe = None
# chosenEsTimeIndexe = [1,3,5]

# ## modeling "full" calculation:
aCalc = cCalculation('Sim1', es, 'pyomo', chosenEsTimeIndexe)
aCalc.doModelingAsOneSegment()

# print Model-Charactaricstics:
es.printModel()
es.printVariables()
es.printEquations()

solverProps = {'gapFrac': gapFrac, 
               'timelimit': timelimit,
               'solver': solver_name, 
               'displaySolverOutput' : displaySolverOutput,
               }
if solver_name == 'gurobi': solverProps['threads'] = nrOfThreads

# ## solving calculation ##

aCalc.solve(solverProps, nameSuffix = '_' + solver_name)

# -> for analysis of results, see separate postprocessing-script!
# Out:
# !!! ACHTUNG in Speicher__Q_th_load : Binärdefinition mit großem Max-Wert (10000). Ggf. falsche Ergebnisse !!!
# !!! ACHTUNG in Speicher__Q_th_unload : Binärdefinition mit großem Max-Wert (10000). Ggf. falsche Ergebnisse !!!
# finalize all MEs...
# Kessel
# Waermelast
# Gastarif
# Einspeisung
# BHKW2
# Speicher
# Gas
# Fernwaerme
# Strom
# globalComp
# costs
# CO2
# PE
# Q_th_Last
# Q_Gas
# Q_th
# P_el
# Q_th_load
# Q_th_unload
# Q_fu
# Q_fu
# Q_th
# P_el
# modeling costs
# modeling CO2
# modeling PE
# declareVarsAndEqs Q_fu
# declareVarsAndEqs Q_th
# declareVarsAndEqs Q_th_Last
# declareVarsAndEqs Q_Gas
# declareVarsAndEqs P_el
# declareVarsAndEqs Q_fu
# declareVarsAndEqs P_el
# declareVarsAndEqs Q_th
# declareVarsAndEqs Q_th_load
# declareVarsAndEqs Q_th_unload
#
# ##############################################################
# ########## Short String Description of Energysystem ##########
#
# buses:
#   Fernwaerme:
#     In-Flows:
#     - Q_th:
#         comp: Kessel
#     - Q_th:
#         comp: BHKW2
#     - Q_th_unload:
#         comp: Speicher
#     Out-Flows:
#     - Q_th_Last:
#         comp: Waermelast
#     - Q_th_load:
#         comp: Speicher
#     class: cBus
#   Gas:
#     In-Flows:
#     - Q_Gas:
#         comp: Gastarif
#     Out-Flows:
#     - Q_fu:
#         comp: Kessel
#     - Q_fu:
#         comp: BHKW2
#     class: cBus
#   Strom:
#     In-Flows:
#     - P_el:
#         comp: BHKW2
#     Out-Flows:
#     - P_el:
#         comp: Einspeisung
#     class: cBus
# components:
#   BHKW2:
#     In-Flows:
#     - Q_fu:
#         bus: Gas
#     Out-Flows:
#     - P_el:
#         bus: Strom
#     - Q_th:
#         bus: Fernwaerme
#     class: cKWK
#   Einspeisung:
#     In-Flows:
#     - P_el:
#         bus: Strom
#     Out-Flows: []
#     class: cSink
#   Gastarif:
#     In-Flows: []
#     Out-Flows:
#     - Q_Gas:
#         bus: Gas
#     class: cSource
#   Kessel:
#     In-Flows:
#     - Q_fu:
#         bus: Gas
#     Out-Flows:
#     - Q_th:
#         bus: Fernwaerme
#     class: cKessel
#   Speicher:
#     In-Flows:
#     - Q_th_load:
#         bus: Fernwaerme
#     Out-Flows:
#     - Q_th_unload:
#         bus: Fernwaerme
#     class: cStorage
#     isStorage: true
#   Waermelast:
#     In-Flows:
#     - Q_th_Last:
#         bus: Fernwaerme
#     Out-Flows: []
#     class: cSink
# flows:
# - bus: Fernwaerme
#   comp: Waermelast
#   isInputInComp: true
#   label: Q_th_Last
# - bus: Gas
#   comp: Gastarif
#   isInputInComp: false
#   label: Q_Gas
# - bus: Fernwaerme
#   comp: Kessel
#   isInputInComp: false
#   label: Q_th
# - bus: Strom
#   comp: Einspeisung
#   isInputInComp: true
#   label: P_el
# - bus: Fernwaerme
#   comp: Speicher
#   isInputInComp: true
#   label: Q_th_load
# - bus: Fernwaerme
#   comp: Speicher
#   isInputInComp: false
#   label: Q_th_unload
# - bus: Gas
#   comp: BHKW2
#   isInputInComp: true
#   label: Q_fu
# - bus: Gas
#   comp: Kessel
#   isInputInComp: true
#   label: Q_fu
# - bus: Fernwaerme
#   comp: BHKW2
#   isInputInComp: false
#   label: Q_th
# - bus: Strom
#   comp: BHKW2
#   isInputInComp: false
#   label: P_el
#
#
# ##############################################################
# ################# Variables of Energysystem ##################
#
# ############# a) as list : ################
#
#
# ############# b) structured : ################
#
#
# ##############################################################
# ################# Equations of Energysystem ##################
#
# Components:
#   BHKW2:
#     _self:
#     - 'eq linearFlowRelation_0[0 of 9]: 0.5* Q_fu.val[0] + -1.0* Q_th.val[0] = 0'
#     - 'eq linearFlowRelation_1[0 of 9]: 0.4* Q_fu.val[0] + -1.0* P_el.val[0] = 0'
#     featureOn:
#     - 'eq SwitchOnOff_andOn[0 of 8]: 1.0* BHKW2.switchOn[1] + -1.0* BHKW2.switchOff[1]
#       + -1.0* BHKW2.on[1] + 1.0* BHKW2.on[0] = 0'
#     - 'eq SwitchOnOffAtFirstTime[0 of 1]: 1.0* BHKW2.switchOn[0] + -1.0* BHKW2.switchOff[0]
#       + -1.0* BHKW2.on[0] = -1'
#     - 'eq NrSwitchOn[0 of 1]: 1.0* BHKW2.nrSwitchOn[0] + ∑(-1.0* BHKW2.switchOn[0]+..)
#       = 0'
#     - 'eq On_Constraint_1[0 of 9]: -1.0* Q_fu.val[0] + -1.0* P_el.val[0] + -1.0* Q_th.val[0]
#       + 1e-05* BHKW2.on[0] <= 0'
#     - 'eq On_Constraint_2[0 of 9]: 0.333333* Q_fu.val[0] + 0.333333* P_el.val[0] +
#       0.333333* Q_th.val[0] + -686.667* BHKW2.on[0] <= 0'
#     - 'eq SwitchOnOrSwitchOff[0 of 9]: 1.0* BHKW2.switchOn[0] + 1.0* BHKW2.switchOff[0]
#       <= 1'
#   Einspeisung:
#     _self: []
#     featureOn: []
#   Gastarif:
#     _self: []
#     featureOn: []
#   Kessel:
#     _self:
#     - 'eq linearFlowRelation_0[0 of 9]: 0.5* Q_fu.val[0] + -1.0* Q_th.val[0] = 0'
#     featureOn:
#     - 'eq On_Constraint_1[0 of 9]: -1.0* Q_fu.val[0] + -1.0* Q_th.val[0] + 1e-05*
#       Kessel.on[0] <= 0'
#     - 'eq On_Constraint_2[0 of 9]: 0.5* Q_fu.val[0] + 0.5* Q_th.val[0] + -125.0* Kessel.on[0]
#       <= 0'
#   Speicher:
#     _self:
#     - 'eq charge_state_start[0 of 1]: 1.0* Speicher.charge_state[0] = 0'
#     - 'eq charge_state[0 of 9]: -0.92* Speicher.charge_state[0] + 1.0* Speicher.charge_state[1]
#       + -0.9* Q_th_load.val[0] + 1.0* Q_th_unload.val[0] = 0'
#     - 'eq nettoFlow[0 of 9]: 1.0* Speicher.nettoFlow[0] + 1.0* Q_th_load.val[0] +
#       -1.0* Q_th_unload.val[0] = 0'
#     - 'eq eq_charge_state_end_max[0 of 1]: 1.0* Speicher.charge_state[9] <= 10'
#     featureOn: []
#     feature_avoidInAndOutAtOnce:
#     - 'eq flowLock[0 of 9]: 1.0* Q_th_load.on[0] + 1.0* Q_th_unload.on[0] <= 1.1'
#     invest:
#       _self:
#       - 'eq max_via_InvestmentSize[0 of 10]: 1.0* Speicher.charge_state[0] + -1.0*
#         invest.used_capacity_inFlowHours[0] <= 0'
#       - 'eq min_via_investmentSize[0 of 10]: -1.0* Speicher.charge_state[0] + 0.0*
#         invest.used_capacity_inFlowHours[0] <= 0'
#       segmentedInvestcosts:
#         _self:
#         - 'eq ICanOnlyBeInOneSegment[0 of 9]: 1.0* seg_0.onSeg_0[0] + 1.0* seg_1.onSeg_1[0]
#           = 1'
#         - 'eq Lambda_onSeg_0[0 of 9]: -1.0* seg_0.onSeg_0[0] + 1.0* seg_0.lambda1_0[0]
#           + 1.0* seg_0.lambda2_0[0] = 0'
#         - 'eq Lambda_onSeg_1[0 of 9]: -1.0* seg_1.onSeg_1[0] + 1.0* seg_1.lambda1_1[0]
#           + 1.0* seg_1.lambda2_1[0] = 0'
#         - 'eq used_capacity_inFlowHours_lambda[0 of 9]: -1.0* invest.used_capacity_inFlowHours[0]
#           + 5.0* seg_0.lambda1_0[0] + 25.0* seg_0.lambda2_0[0] + 25.0* seg_1.lambda1_1[0]
#           + 100.0* seg_1.lambda2_1[0] = 0'
#         - 'eq investCosts_segmented_costs_lambda[0 of 9]: -1.0* invest.investCosts_segmented_costs[0]
#           + 50.0* seg_0.lambda1_0[0] + 250.0* seg_0.lambda2_0[0] + 250.0* seg_1.lambda1_1[0]
#           + 800.0* seg_1.lambda2_1[0] = 0'
#         - 'eq investCosts_segmented_PE_lambda[0 of 9]: -1.0* invest.investCosts_segmented_PE[0]
#           + 5.0* seg_0.lambda1_0[0] + 25.0* seg_0.lambda2_0[0] + 25.0* seg_1.lambda1_1[0]
#           + 100.0* seg_1.lambda2_1[0] = 0'
#         seg_0: []
#         seg_1: []
#   Waermelast:
#     _self: []
#     featureOn: []
# buses:
#   Fernwaerme:
#     _self:
#     - 'eq busBalance[0 of 9]: 1.0* Q_th.val[0] + 1.0* Q_th.val[0] + 1.0* Q_th_unload.val[0]
#       + -1.0* Q_th_Last.val[0] + -1.0* Q_th_load.val[0] + -1.0* Fernwaerme.excessOut[0]
#       + 1.0* Fernwaerme.excessIn[0] = 0'
#     featureOn: []
#   Gas:
#     _self:
#     - 'eq busBalance[0 of 9]: 1.0* Q_Gas.val[0] + -1.0* Q_fu.val[0] + -1.0* Q_fu.val[0]
#       + -1.0* Gas.excessOut[0] + 1.0* Gas.excessIn[0] = 0'
#     featureOn: []
#   Strom:
#     _self:
#     - 'eq busBalance[0 of 9]: 1.0* P_el.val[0] + -1.0* P_el.val[0] + -1.0* Strom.excessOut[0]
#       + 1.0* Strom.excessIn[0] = 0'
#     featureOn: []
# flows:
#   BHKW2__P_el:
#     _self:
#     - 'eq sumFlowHours[0 of 1]: ∑(1.0* P_el.val[0]+..) + -1.0* P_el.sumFlowHours[0]
#       = 0'
#     featureOn:
#     - 'eq On_Constraint_1[0 of 9]: -1.0* P_el.val[0] + 5.0* P_el.on[0] <= 0'
#     - 'eq On_Constraint_2[0 of 9]: 1.0* P_el.val[0] + -60.0* P_el.on[0] <= 0'
#   BHKW2__Q_fu:
#     _self:
#     - 'eq sumFlowHours[0 of 1]: ∑(1.0* Q_fu.val[0]+..) + -1.0* Q_fu.sumFlowHours[0]
#       = 0'
#     featureOn: []
#   BHKW2__Q_th:
#     _self:
#     - 'eq sumFlowHours[0 of 1]: ∑(1.0* Q_th.val[0]+..) + -1.0* Q_th.sumFlowHours[0]
#       = 0'
#     featureOn: []
#   Einspeisung__P_el:
#     _self:
#     - 'eq sumFlowHours[0 of 1]: ∑(1.0* P_el.val[0]+..) + -1.0* P_el.sumFlowHours[0]
#       = 0'
#     featureOn: []
#   Gastarif__Q_Gas:
#     _self:
#     - 'eq sumFlowHours[0 of 1]: ∑(1.0* Q_Gas.val[0]+..) + -1.0* Q_Gas.sumFlowHours[0]
#       = 0'
#     featureOn: []
#   Kessel__Q_fu:
#     _self:
#     - 'eq sumFlowHours[0 of 1]: ∑(1.0* Q_fu.val[0]+..) + -1.0* Q_fu.sumFlowHours[0]
#       = 0'
#     featureOn: []
#   Kessel__Q_th:
#     _self:
#     - 'eq sumFlowHours[0 of 1]: ∑(1.0* Q_th.val[0]+..) + -1.0* Q_th.sumFlowHours[0]
#       = 0'
#     - 'eq loadFactor_max[0 of 1]: 1.0* Q_th.sumFlowHours[0] + -9.0* invest.nominal_val[0]
#       <= 0'
#     - 'eq loadFactor_min[0 of 1]: -1.0* Q_th.sumFlowHours[0] + 0.9* invest.nominal_val[0]
#       <= 0'
#     featureOn:
#     - 'eq var_off[0 of 9]: 1.0* Q_th.off[0] + 1.0* Q_th.on[0] = 1'
#     - 'eq SwitchOnOff_andOn[0 of 8]: 1.0* Q_th.switchOn[1] + -1.0* Q_th.switchOff[1]
#       + -1.0* Q_th.on[1] + 1.0* Q_th.on[0] = 0'
#     - 'eq SwitchOnOffAtFirstTime[0 of 1]: 1.0* Q_th.switchOn[0] + -1.0* Q_th.switchOff[0]
#       + -1.0* Q_th.on[0] = -1'
#     - 'eq NrSwitchOn[0 of 1]: 1.0* Q_th.nrSwitchOn[0] + ∑(-1.0* Q_th.switchOn[0]+..)
#       = 0'
#     - 'eq onHours_firstTimeStep[0 of 1]: 1.0* Q_th.onHours[0] + -1.0* Q_th.on[0] =
#       0'
#     - 'eq offHours_firstTimeStep[0 of 1]: 1.0* Q_th.offHours[0] + -1.0* Q_th.off[0]
#       = 0'
#     - 'eq On_Constraint_1[0 of 9]: -1.0* Q_th.val[0] + 5.0* Q_th.on[0] <= 0'
#     - 'eq On_Constraint_2[0 of 9]: 1.0* Q_th.val[0] + -50.0* Q_th.on[0] <= 0'
#     - 'eq SwitchOnOrSwitchOff[0 of 9]: 1.0* Q_th.switchOn[0] + 1.0* Q_th.switchOff[0]
#       <= 1'
#     - 'eq onHours_constraint_1[0 of 9]: 1.0* Q_th.onHours[0] + -9.0* Q_th.on[0] <=
#       0'
#     - 'eq onHours_constraint_2a[0 of 8]: 1.0* Q_th.onHours[1] + -1.0* Q_th.onHours[0]
#       <= 1.0'
#     - 'eq onHours_constraint_2b[0 of 8]: -1.0* Q_th.onHours[1] + 1.0* Q_th.onHours[0]
#       + 9.0* Q_th.on[1] <= 8.0'
#     - 'eq offHours_constraint_1[0 of 9]: 1.0* Q_th.offHours[0] + -9.0* Q_th.off[0]
#       <= 0'
#     - 'eq offHours_constraint_2a[0 of 8]: 1.0* Q_th.offHours[1] + -1.0* Q_th.offHours[0]
#       <= 1.0'
#     - 'eq offHours_constraint_2b[0 of 8]: -1.0* Q_th.offHours[1] + 1.0* Q_th.offHours[0]
#       + 9.0* Q_th.off[1] <= 8.0'
#     invest:
#     - 'eq max_via_InvestmentSize[0 of 9]: 1.0* Q_th.val[0] + -1.0* invest.nominal_val[0]
#       <= 0'
#   Speicher__Q_th_load:
#     _self:
#     - 'eq sumFlowHours[0 of 1]: ∑(1.0* Q_th_load.val[0]+..) + -1.0* Q_th_load.sumFlowHours[0]
#       = 0'
#     featureOn:
#     - 'eq On_Constraint_1[0 of 9]: -1.0* Q_th_load.val[0] + 1e-05* Q_th_load.on[0]
#       <= 0'
#     - 'eq On_Constraint_2[0 of 9]: 1.0* Q_th_load.val[0] + -10000.0* Q_th_load.on[0]
#       <= 0'
#   Speicher__Q_th_unload:
#     _self:
#     - 'eq sumFlowHours[0 of 1]: ∑(1.0* Q_th_unload.val[0]+..) + -1.0* Q_th_unload.sumFlowHours[0]
#       = 0'
#     featureOn:
#     - 'eq On_Constraint_1[0 of 9]: -1.0* Q_th_unload.val[0] + 1e-05* Q_th_unload.on[0]
#       <= 0'
#     - 'eq On_Constraint_2[0 of 9]: 1.0* Q_th_unload.val[0] + -10000.0* Q_th_unload.on[0]
#       <= 0'
#   Waermelast__Q_th_Last:
#     _self:
#     - 'eq sumFlowHours[0 of 1]: ∑(1.0* Q_th_Last.val[0]+..) + -1.0* Q_th_Last.sumFlowHours[0]
#       = 0'
#     featureOn: []
# globals:
#   CO2:
#     _self: []
#     all:
#       _self:
#       - 'eq sum[0 of 1]: 1.0* operation.sum[0] + 1.0* invest.sum[0] + -1.0* all.sum[0]
#         = 0'
#       shares:
#       - 'eq CO2_operation[0 of 1]: -1.0* shares.CO2_operation[0] + 1.0* operation.sum[0]
#         = 0'
#       - 'eq CO2_invest[0 of 1]: -1.0* shares.CO2_invest[0] + 1.0* invest.sum[0] =
#         0'
#     invest:
#       _self:
#       - 'eq sum[0 of 1]: -1.0* invest.sum[0] + 0.01* invest.used_capacity_inFlowHours[0]
#         = 0'
#       shares:
#       - 'eq Speicher_specificCosts[0 of 1]: -1.0* shares.Speicher_specificCosts[0]
#         + 0.01* invest.used_capacity_inFlowHours[0] = 0'
#     operation:
#       _self:
#       - 'eq bilanz[0 of 9]: -1.0* operation.sum_TS[0] + 1000.0* Kessel.on[0] + 0.3*
#         Q_Gas.val[0] = 0'
#       - 'eq sum[0 of 1]: ∑(1.0* operation.sum_TS[0]+..) + -1.0* operation.sum[0] =
#         0'
#       shares:
#       - 'eq Kessel_costsPerRunningHour[0 of 1]: -1.0* shares.Kessel_costsPerRunningHour[0]
#         + ∑(1000.0* Kessel.on[0]+..) = 0'
#       - 'eq Gastarif__Q_Gas_costsPerFlowHour[0 of 1]: -1.0* shares.Gastarif__Q_Gas_costsPerFlowHour[0]
#         + ∑(0.3* Q_Gas.val[0]+..) = 0'
#   PE:
#     _self: []
#     all:
#       _self:
#       - 'eq sum[0 of 1]: 1.0* operation.sum[0] + 1.0* invest.sum[0] + -1.0* all.sum[0]
#         = 0'
#       shares:
#       - 'eq PE_operation[0 of 1]: -1.0* shares.PE_operation[0] + 1.0* operation.sum[0]
#         = 0'
#       - 'eq PE_invest[0 of 1]: -1.0* shares.PE_invest[0] + 1.0* invest.sum[0] = 0'
#     invest:
#       _self:
#       - 'eq sum[0 of 1]: -1.0* invest.sum[0] + 2.0* invest.nominal_val[0] + 1.0* invest.investCosts_segmented_PE[0]
#         = 0'
#       shares:
#       - 'eq Kessel__Q_th_specificCosts[0 of 1]: -1.0* shares.Kessel__Q_th_specificCosts[0]
#         + 2.0* invest.nominal_val[0] = 0'
#       - 'eq Speicher_linearSegments[0 of 1]: -1.0* shares.Speicher_linearSegments[0]
#         + 1.0* invest.investCosts_segmented_PE[0] = 0'
#     operation:
#       _self:
#       - 'eq bilanz[0 of 9]: -1.0* operation.sum_TS[0] = 0'
#       - 'eq sum[0 of 1]: ∑(1.0* operation.sum_TS[0]+..) + -1.0* operation.sum[0] =
#         0'
#       shares: []
#   _self:
#   - 'obj: 1.0* penalty.sum[0] + 1.0* operation.sum[0] + 1.0* invest.sum[0] = 0'
#   costs:
#     _self: []
#     all:
#       _self:
#       - 'eq sum[0 of 1]: 1.0* operation.sum[0] + 1.0* invest.sum[0] + -1.0* all.sum[0]
#         = 0'
#       shares:
#       - 'eq costs_operation[0 of 1]: -1.0* shares.costs_operation[0] + 1.0* operation.sum[0]
#         = 0'
#       - 'eq costs_invest[0 of 1]: -1.0* shares.costs_invest[0] + 1.0* invest.sum[0]
#         = 0'
#     invest:
#       _self:
#       - 'eq sum[0 of 1]: -1.0* invest.sum[0] + 10.0* invest.nominal_val[0] + 0.01*
#         invest.used_capacity_inFlowHours[0] + 1.0* invest.investCosts_segmented_costs[0]
#         = -1000'
#       shares:
#       - 'eq Kessel__Q_th_fixCosts[0 of 1]: -1.0* shares.Kessel__Q_th_fixCosts[0] =
#         -1000'
#       - 'eq Kessel__Q_th_specificCosts[0 of 1]: -1.0* shares.Kessel__Q_th_specificCosts[0]
#         + 10.0* invest.nominal_val[0] = 0'
#       - 'eq Speicher_specificCosts[0 of 1]: -1.0* shares.Speicher_specificCosts[0]
#         + 0.01* invest.used_capacity_inFlowHours[0] = 0'
#       - 'eq Speicher_linearSegments[0 of 1]: -1.0* shares.Speicher_linearSegments[0]
#         + 1.0* invest.investCosts_segmented_costs[0] = 0'
#     operation:
#       _self:
#       - 'eq bilanz[0 of 9]: -1.0* operation.sum_TS[0] + 0.2* operation.sum_TS[0] +
#         0.01* Q_th.switchOn[0] + 0.0* Kessel.on[0] + 0.04* Q_Gas.val[0] + -40.0* P_el.val[0]
#         + 0.01* BHKW2.switchOn[0] = 0'
#       - 'eq sum[0 of 1]: ∑(1.0* operation.sum_TS[0]+..) + -1.0* operation.sum[0] =
#         0'
#       shares:
#       - 'eq CO2_specificShareToOtherEffects_operation[0 of 1]: -1.0* shares.CO2_specificShareToOtherEffects_operation[0]
#         + ∑(0.2* operation.sum_TS[0]+..) = 0'
#       - 'eq Kessel__Q_th_switchOnCosts[0 of 1]: -1.0* shares.Kessel__Q_th_switchOnCosts[0]
#         + ∑(0.01* Q_th.switchOn[0]+..) = 0'
#       - 'eq Kessel_costsPerRunningHour[0 of 1]: -1.0* shares.Kessel_costsPerRunningHour[0]
#         + ∑(0.0* Kessel.on[0]+..) = 0'
#       - 'eq Gastarif__Q_Gas_costsPerFlowHour[0 of 1]: -1.0* shares.Gastarif__Q_Gas_costsPerFlowHour[0]
#         + ∑(0.04* Q_Gas.val[0]+..) = 0'
#       - 'eq Einspeisung__P_el_costsPerFlowHour[0 of 1]: -1.0* shares.Einspeisung__P_el_costsPerFlowHour[0]
#         + ∑(-40.0* P_el.val[0]+..) = 0'
#       - 'eq BHKW2_switchOnCosts[0 of 1]: -1.0* shares.BHKW2_switchOnCosts[0] + ∑(0.01*
#         BHKW2.switchOn[0]+..) = 0'
#   penalty:
#     _self:
#     - 'eq bilanz[0 of 9]: -1.0* penalty.sum_TS[0] + 1e+05* Gas.excessIn[0] + 1e+05*
#       Gas.excessOut[0] + 1e+05* Fernwaerme.excessIn[0] + 1e+05* Fernwaerme.excessOut[0]
#       + 1e+05* Strom.excessIn[0] + 1e+05* Strom.excessOut[0] = 0'
#     - 'eq sum[0 of 1]: ∑(1.0* penalty.sum_TS[0]+..) + -1.0* penalty.sum[0] = 0'
#     shares:
#     - 'eq Gas_excessCostsPerFlowHour[0 of 1]: -1.0* shares.Gas_excessCostsPerFlowHour[0]
#       + ∑(1e+05* Gas.excessIn[0]+..) = 0'
#     - 'eq Gas_excessCostsPerFlowHour[0 of 1]: -1.0* shares.Gas_excessCostsPerFlowHour[0]
#       + ∑(1e+05* Gas.excessOut[0]+..) = 0'
#     - 'eq Fernwaerme_excessCostsPerFlowHour[0 of 1]: -1.0* shares.Fernwaerme_excessCostsPerFlowHour[0]
#       + ∑(1e+05* Fernwaerme.excessIn[0]+..) = 0'
#     - 'eq Fernwaerme_excessCostsPerFlowHour[0 of 1]: -1.0* shares.Fernwaerme_excessCostsPerFlowHour[0]
#       + ∑(1e+05* Fernwaerme.excessOut[0]+..) = 0'
#     - 'eq Strom_excessCostsPerFlowHour[0 of 1]: -1.0* shares.Strom_excessCostsPerFlowHour[0]
#       + ∑(1e+05* Strom.excessIn[0]+..) = 0'
#     - 'eq Strom_excessCostsPerFlowHour[0 of 1]: -1.0* shares.Strom_excessCostsPerFlowHour[0]
#       + ∑(1e+05* Strom.excessOut[0]+..) = 0'
# others: {}
#
#
# ##############################################################
# ##################### solving ################################
#
# no of Eqs   (single):75 (241)
# no of InEqs (single):27 (217)
# no of Vars  (single):100 (429)
# Solver log file: '/Users/felix/Documents/Dokumente - eigene/Arbeit_SE_Trainee/flixOptSE/flixOpt/examples_notebooks/results/2024-05-25_Sim1_cbc_solver.log'
# Solver solution file: '/var/folders/1z/xs11s8cd563_dhtnmk53bxpr0000gn/T/tmp3amr7z_2.pyomo.soln'
# Solver problem files: ('/var/folders/1z/xs11s8cd563_dhtnmk53bxpr0000gn/T/tmp3amr7z_2.pyomo.lp',)
# Welcome to the CBC MILP Solver
# Version: 2.10.10
# Build Date: Aug  1 2023
#
# command line - /Users/felix/opt/anaconda3/bin/cbc -ratio 0.0001 -sec 3600 -printingOptions all -import /var/folders/1z/xs11s8cd563_dhtnmk53bxpr0000gn/T/tmp3amr7z_2.pyomo.lp -stat=1 -solve -solu /var/folders/1z/xs11s8cd563_dhtnmk53bxpr0000gn/T/tmp3amr7z_2.pyomo.soln (default strategy 1)
# ratioGap was changed from 0 to 0.0001
# seconds was changed from 1e+100 to 3600
# Option for printingOptions changed from normal to all
# Presolve 290 (-168) rows, 269 (-144) columns and 841 (-667) elements
# Statistics for presolved model
# Original problem has 117 integers (117 of which binary)
# Presolved problem has 97 integers (97 of which binary)
# ==== 168 zero objective 7 different
# 9 variables have objective of -40
# 168 variables have objective of 0
# 19 variables have objective of 0.01
# 9 variables have objective of 0.1
# 1 variables have objective of 1
# 9 variables have objective of 200
# 54 variables have objective of 100000
# ==== absolute objective values 7 different
# 168 variables have objective of 0
# 19 variables have objective of 0.01
# 9 variables have objective of 0.1
# 1 variables have objective of 1
# 9 variables have objective of 40
# 9 variables have objective of 200
# 54 variables have objective of 100000
# ==== for integers 70 zero objective 3 different
# 70 variables have objective of 0
# 18 variables have objective of 0.01
# 9 variables have objective of 200
# ==== for integers absolute objective values 3 different
# 70 variables have objective of 0
# 18 variables have objective of 0.01
# 9 variables have objective of 200
# ===== end objective counts
#
#
# Problem has 290 rows, 269 columns (101 with objective) and 841 elements
# There are 74 singletons with objective
# Column breakdown:
# 55 of type 0.0->inf, 71 of type 0.0->up, 0 of type lo->inf,
# 0 of type lo->up, 9 of type free, 0 of type fixed,
# 0 of type -inf->0.0, 1 of type -inf->up, 133 of type 0.0->1.0
# Row breakdown:
# 71 of type E 0.0, 9 of type E 1.0, 0 of type E -1.0,
# 17 of type E other, 0 of type G 0.0, 0 of type G 1.0,
# 0 of type G other, 127 of type L 0.0, 31 of type L 1.0,
# 34 of type L other, 0 of type Range 0.0->1.0, 1 of type Range other,
# 0 of type Free
# Continuous objective value is -19705.9 - 0.00 seconds
# Cgl0003I 1 fixed, 0 tightened bounds, 68 strengthened rows, 27 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 24 strengthened rows, 12 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 1 strengthened rows, 0 substitutions
# Cgl0004I processed model has 284 rows, 246 columns (76 integer (76 of which binary)) and 880 elements
# Cbc0038I Initial state - 27 integers unsatisfied sum - 5.76285
# Cbc0038I Pass   1: suminf.    0.00000 (0) obj. 4.04803e+07 iterations 40
# Cbc0038I Solution found of 4.04803e+07
# Cbc0038I Relaxing continuous gives 5.61623e+06
# Cbc0038I Before mini branch and bound, 49 integers at bound fixed and 96 continuous
# Cbc0038I Full problem 284 rows 246 columns, reduced to 45 rows 33 columns
# Cbc0038I Mini branch and bound did not improve solution (0.05 seconds)
# Cbc0038I Round again with cutoff of 5.05266e+06
# Cbc0038I Pass   2: suminf.    0.00056 (1) obj. 5.05266e+06 iterations 12
# Cbc0038I Pass   3: suminf.    0.00056 (1) obj. 5.05266e+06 iterations 0
# Cbc0038I Pass   4: suminf.    0.00056 (1) obj. 5.05266e+06 iterations 0
# Cbc0038I Pass   5: suminf.    2.10270 (8) obj. 5.05266e+06 iterations 76
# Cbc0038I Pass   6: suminf.    0.00270 (3) obj. 5.05266e+06 iterations 14
# Cbc0038I Pass   7: suminf.    0.00120 (2) obj. 5.05266e+06 iterations 1
# Cbc0038I Pass   8: suminf.    0.00120 (2) obj. 5.05266e+06 iterations 0
# Cbc0038I Pass   9: suminf.    3.22535 (10) obj. 5.05266e+06 iterations 50
# Cbc0038I Pass  10: suminf.    0.00000 (0) obj. 5.05266e+06 iterations 7
# Cbc0038I Solution found of 5.05266e+06
# Cbc0038I Relaxing continuous gives 1.99175e+06
# Cbc0038I Before mini branch and bound, 23 integers at bound fixed and 60 continuous
# Cbc0038I Full problem 284 rows 246 columns, reduced to 176 rows 125 columns - 6 fixed gives 139, 102 - still too large
# Cbc0038I Full problem 284 rows 246 columns, reduced to 137 rows 102 columns - too large
# Cbc0038I Mini branch and bound did not improve solution (0.07 seconds)
# Cbc0038I Round again with cutoff of 1.58952e+06
# Cbc0038I Pass  11: suminf.    0.70420 (6) obj. 1.58952e+06 iterations 9
# Cbc0038I Pass  12: suminf.    0.49057 (7) obj. 1.58952e+06 iterations 3
# Cbc0038I Pass  13: suminf.    0.00000 (0) obj. 1.58952e+06 iterations 17
# Cbc0038I Solution found of 1.58952e+06
# Cbc0038I Relaxing continuous gives -9173.31
# Cbc0038I Before mini branch and bound, 47 integers at bound fixed and 84 continuous
# Cbc0038I Full problem 284 rows 246 columns, reduced to 104 rows 72 columns
# Cbc0038I Mini branch and bound improved solution from -9173.31 to -10322.2 (0.10 seconds)
# Cbc0038I Freeing continuous variables gives a solution of -10974.6
# Cbc0038I Round again with cutoff of -13510.1
# Cbc0038I Pass  14: suminf.    1.56588 (13) obj. -13510.1 iterations 21
# Cbc0038I Pass  15: suminf.    0.22980 (10) obj. -13510.1 iterations 10
# Cbc0038I Pass  16: suminf.    0.20504 (4) obj. -13510.1 iterations 17
# Cbc0038I Pass  17: suminf.    0.11652 (5) obj. -13510.1 iterations 7
# Cbc0038I Pass  18: suminf.    0.20000 (2) obj. -13510.1 iterations 4
# Cbc0038I Pass  19: suminf.    0.11096 (3) obj. -13510.1 iterations 3
# Cbc0038I Pass  20: suminf.    1.31118 (11) obj. -13510.1 iterations 61
# Cbc0038I Pass  21: suminf.    1.14050 (10) obj. -13510.1 iterations 13
# Cbc0038I Pass  22: suminf.    0.14050 (8) obj. -13510.1 iterations 1
# Cbc0038I Pass  23: suminf.    0.41109 (6) obj. -13510.1 iterations 7
# Cbc0038I Pass  24: suminf.    0.14450 (7) obj. -13510.1 iterations 5
# Cbc0038I Pass  25: suminf.    0.40545 (6) obj. -13510.1 iterations 6
# Cbc0038I Pass  26: suminf.    0.13886 (7) obj. -13510.1 iterations 5
# Cbc0038I Pass  27: suminf.    1.25557 (9) obj. -13510.1 iterations 17
# Cbc0038I Pass  28: suminf.    0.15557 (6) obj. -13510.1 iterations 7
# Cbc0038I Pass  29: suminf.    0.32365 (5) obj. -13510.1 iterations 5
# Cbc0038I Pass  30: suminf.    0.15976 (5) obj. -13510.1 iterations 4
# Cbc0038I Pass  31: suminf.    0.31781 (5) obj. -13510.1 iterations 4
# Cbc0038I Pass  32: suminf.    0.15393 (5) obj. -13510.1 iterations 3
# Cbc0038I Pass  33: suminf.    1.16236 (6) obj. -13510.1 iterations 15
# Cbc0038I Pass  34: suminf.    0.16236 (4) obj. -13510.1 iterations 4
# Cbc0038I Pass  35: suminf.    0.40000 (4) obj. -13510.1 iterations 5
# Cbc0038I Pass  36: suminf.    0.16120 (3) obj. -13510.1 iterations 7
# Cbc0038I Pass  37: suminf.    0.30000 (3) obj. -13510.1 iterations 3
# Cbc0038I Pass  38: suminf.    0.60990 (7) obj. -13510.1 iterations 31
# Cbc0038I Pass  39: suminf.    0.18506 (4) obj. -13510.1 iterations 8
# Cbc0038I Pass  40: suminf.    0.40000 (4) obj. -13510.1 iterations 4
# Cbc0038I Pass  41: suminf.    3.45532 (23) obj. -13510.1 iterations 39
# Cbc0038I Pass  42: suminf.    0.89368 (11) obj. -13510.1 iterations 18
# Cbc0038I Pass  43: suminf.    0.89368 (11) obj. -13510.1 iterations 0
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 16 integers at bound fixed and 60 continuous
# Cbc0038I Full problem 284 rows 246 columns, reduced to 221 rows 141 columns - 3 fixed gives 202, 133 - still too large
# Cbc0038I Full problem 284 rows 246 columns, reduced to 198 rows 130 columns - too large
# Cbc0038I Mini branch and bound did not improve solution (0.13 seconds)
# Cbc0038I After 0.13 seconds - Feasibility pump exiting with objective of -10974.6 - took 0.10 seconds
# Cbc0012I Integer solution of -10974.612 found by feasibility pump after 0 iterations and 0 nodes (0.13 seconds)
# Cbc0038I Full problem 284 rows 246 columns, reduced to 148 rows 174 columns - 1 fixed gives 137, 170 - still too large
# Cbc0038I Full problem 284 rows 246 columns, reduced to 131 rows 167 columns - too large
# Cbc0031I 40 added rows had average density of 11.075
# Cbc0013I At root node, 40 cuts changed objective from -19426.337 to -18455.839 in 25 passes
# Cbc0014I Cut generator 0 (Probing) - 136 row cuts average 2.1 elements, 0 column cuts (0 active)  in 0.016 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 75 row cuts average 25.2 elements, 0 column cuts (0 active)  in 0.009 seconds - new frequency is 1
# Cbc0014I Cut generator 2 (Knapsack) - 1 row cuts average 2.0 elements, 0 column cuts (0 active)  in 0.016 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.002 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 81 row cuts average 6.1 elements, 0 column cuts (0 active)  in 0.008 seconds - new frequency is 1
# Cbc0014I Cut generator 5 (FlowCover) - 9 row cuts average 3.0 elements, 0 column cuts (0 active)  in 0.012 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 102 row cuts average 17.6 elements, 0 column cuts (0 active)  in 0.010 seconds - new frequency is 1
# Cbc0010I After 0 nodes, 1 on tree, -10974.612 best solution, best possible -18455.839 (0.30 seconds)
# Cbc0012I Integer solution of -11036.414 found by DiveCoefficient after 1247 iterations and 4 nodes (0.43 seconds)
# Cbc0012I Integer solution of -11036.414 found by DiveCoefficient after 1271 iterations and 4 nodes (0.44 seconds)
# Cbc0012I Integer solution of -11153.865 found by DiveCoefficient after 1545 iterations and 8 nodes (0.46 seconds)
# Cbc0038I Full problem 284 rows 246 columns, reduced to 104 rows 126 columns
# Cbc0038I Full problem 284 rows 246 columns, reduced to 74 rows 111 columns
# Cbc0012I Integer solution of -11158.814 found by DiveCoefficient after 4338 iterations and 136 nodes (0.69 seconds)
# Cbc0012I Integer solution of -11168.53 found by DiveCoefficient after 4384 iterations and 137 nodes (0.69 seconds)
# Cbc0016I Integer solution of -11172.937 found by strong branching after 4796 iterations and 151 nodes (0.73 seconds)
# Cbc0004I Integer solution of -11263.124 found after 4797 iterations and 152 nodes (0.73 seconds)
# Cbc0012I Integer solution of -11362.409 found by DiveCoefficient after 5035 iterations and 156 nodes (0.75 seconds)
# Cbc0016I Integer solution of -11413.979 found by strong branching after 5243 iterations and 161 nodes (0.77 seconds)
# Cbc0016I Integer solution of -11417.105 found by strong branching after 5310 iterations and 162 nodes (0.77 seconds)
# Cbc0038I Full problem 284 rows 246 columns, reduced to 97 rows 115 columns
# Cbc0012I Integer solution of -11497.322 found by DiveCoefficient after 9704 iterations and 266 nodes (1.20 seconds)
# Cbc0012I Integer solution of -11597.874 found by DiveCoefficient after 10015 iterations and 274 nodes (1.22 seconds)
# Cbc0001I Search completed - best objective -11597.87362448931, took 13166 iterations and 338 nodes (1.44 seconds)
# Cbc0032I Strong branching done 2704 times (30611 iterations), fathomed 91 nodes and fixed 63 variables
# Cbc0035I Maximum depth 11, 156 variables fixed on reduced cost
# Cuts at root node changed objective from -19426.3 to -18455.8
# Probing was tried 255 times and created 699 cuts of which 0 were active after adding rounds of cuts (0.045 seconds)
# Gomory was tried 249 times and created 413 cuts of which 0 were active after adding rounds of cuts (0.034 seconds)
# Knapsack was tried 25 times and created 1 cuts of which 0 were active after adding rounds of cuts (0.016 seconds)
# Clique was tried 25 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.002 seconds)
# MixedIntegerRounding2 was tried 249 times and created 537 cuts of which 0 were active after adding rounds of cuts (0.039 seconds)
# FlowCover was tried 25 times and created 9 cuts of which 0 were active after adding rounds of cuts (0.012 seconds)
# TwoMirCuts was tried 249 times and created 339 cuts of which 0 were active after adding rounds of cuts (0.044 seconds)
# ZeroHalf was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
# ImplicationCuts was tried 369 times and created 74 cuts of which 0 were active after adding rounds of cuts (0.004 seconds)
#
# Result - Optimal solution found
#
# Objective value:                -11597.87362449
# Enumerated nodes:               338
# Total iterations:               13166
# Time (CPU seconds):             1.44
# Time (Wallclock seconds):       1.48
#
# Total time (CPU seconds):       1.45   (Wallclock seconds):       1.49
#
# termination message: "not implemented for solver yet"
#
# ##############################################################
# ################### finished #################################
#
# costs in €:
#   operation: -13898.874
#   invest   : 2301.0
#   sum      : -11597.874
# CO2 in kg:
#   operation: 1293.1865
#   invest   : 1.0
#   sum      : 1294.1865
# PE in kWh_PE:
#   operation: 0.0
#   invest   : 200.0
#   sum      : 200.0
# SUM              : ...todo...
# penaltyCosts     : 0.0
# ––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––––
# Result of Obj : -11597.874
# lower bound   : -11597.87362449
#
#
# ##############################################################
# Effects:
#   CO2 [kg]:
#     invest: '1.0'
#     operation: '1293.1865'
#     sum: '1294.1865'
#   PE [kWh_PE]:
#     invest: '200.0'
#     operation: '0.0'
#     sum: '200.0'
#   costs [€]:
#     invest: '2301.0'
#     operation: '-13898.874'
#     sum: '-11597.874'
# Invest-Decisions:
#   invested:
#     Kessel__Q_th: 50.0
#     Speicher: 100.0
#   not invested: {}
# Result of Obj: -11597.874
# busesWithExcess: []
# lower bound: -11597.87362449
# penaltyCosts: '0.0'
#
# #########################################
# # saved calculation 2024-05-25_Sim1_cbc #
# #########################################
